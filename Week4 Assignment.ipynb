# %% [markdown]
# # Introduction:

# %% [markdown]
# ## Tokyo; The biggest city of Japan
# ## As of 2021, Tokyo has an estimated population of 13,960,236.
# ## Tokyo is the political and economic center of Japan.

# %% [markdown]
# # Business Problem

# %% [markdown]
# ## To start a restaurant
# ## Neighborhood that is most likely to give a good business

# %% [markdown]
# # Data:

# %% [markdown]
# ## Neighbourhoods of Tokyo

# %% [markdown]
# - Neighbourhoods of Tokyo wikipedia page through data scraping.

# %% [markdown]
# ## Geographical coordinates of the neighbourhoods

# %% [markdown]
# - Using Geopy library.

# %% [markdown]
# ## Venue data from Foursquare

# %% [markdown]
# - Using Foursquare API
